# %% [markdown]
# # Airbnb - Data Visualizations Project
#
# ## Investor Approach

# %%
# First of all, we need to import pandas library
import pandas as pd

# Then we can try to read the CSV file for the first time
df = pd.read_csv('./Ireland_Airbnb_Listing__Detailed.csv')
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31907 entries, 0 to 31906
# Data columns (total 85 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            31907 non-null  float64
#  1   listing_url                                   31907 non-null  object
#  2   scrape_id                                     31907 non-null  float64
#  3   last_searched                                 26192 non-null  object
#  4   last_scraped                                  31907 non-null  object
#  5   source                                        31907 non-null  object
#  6   name                                          31907 non-null  object
#  7   description                                   31313 non-null  object
#  8   neighborhood_overview                         14433 non-null  object
#  9   picture_url                                   31907 non-null  object
#  10  host_id                                       31907 non-null  int64
#  11  host_url                                      31907 non-null  object
#  12  host_name                                     30734 non-null  object
#  13  host_since                                    30716 non-null  object
#  14  host_location                                 21482 non-null  object
#  15  host_about                                    12430 non-null  object
#  16  host_response_time                            24838 non-null  object
#  17  host_response_rate                            24838 non-null  object
#  18  host_acceptance_rate                          26517 non-null  object
#  19  host_is_superhost                             31506 non-null  object
#  20  host_thumbnail_url                            30716 non-null  object
#  21  host_picture_url                              30716 non-null  object
#  22  host_neighbourhood                            22494 non-null  object
#  23  host_listings_count                           30716 non-null  float64
#  24  host_total_listings_count                     30716 non-null  float64
#  25  host_verifications                            30716 non-null  object
#  26  host_has_profile_pic                          30716 non-null  object
#  27  host_identity_verified                        30716 non-null  object
#  28  neighbourhood                                 14433 non-null  object
#  29  latitude                                      31907 non-null  float64
#  30  longitude                                     31907 non-null  float64
#  31  property_type                                 31907 non-null  object
#  32  room_type                                     31907 non-null  object
#  33  accommodates                                  31907 non-null  int64
#  34  bathrooms                                     26165 non-null  float64
#  35  bathrooms_text                                31856 non-null  object
#  36  bedrooms                                      29640 non-null  float64
#  37  beds                                          26159 non-null  float64
#  38  amenities                                     31907 non-null  object
#  39  price                                         26181 non-null  object
#  40  minimum_nights                                31907 non-null  int64
#  41  maximum_nights                                31907 non-null  int64
#  42  minimum_minimum_nights                        31902 non-null  float64
#  43  maximum_minimum_nights                        31902 non-null  float64
#  44  minimum_maximum_nights                        31902 non-null  float64
#  45  maximum_maximum_nights                        31902 non-null  float64
#  46  minimum_nights_avg_ntm                        31907 non-null  float64
#  47  maximum_nights_avg_ntm                        31907 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              30672 non-null  object
#  50  availability_30                               31907 non-null  int64
#  51  availability_60                               31907 non-null  int64
#  52  availability_90                               31907 non-null  int64
#  53  availability_365                              31907 non-null  int64
#  54  calendar_last_scraped                         31907 non-null  object
#  55  number_of_reviews                             31907 non-null  int64
#  56  number_of_reviews_ltm                         31907 non-null  int64
#  57  number_of_reviews_l30d                        31907 non-null  int64
#  58  availability_eoy                              31907 non-null  int64
#  59  number_of_reviews_ly                          31907 non-null  int64
#  60  estimated_occupancy_l365d                     31907 non-null  int64
#  61  estimated_revenue_l365d                       26181 non-null  float64
#  62  first_review                                  27692 non-null  object
#  63  last_review                                   27692 non-null  object
#  64  review_scores_rating                          27692 non-null  float64
#  65  review_scores_accuracy                        27689 non-null  float64
#  66  review_scores_cleanliness                     27689 non-null  float64
#  67  review_scores_checkin                         27686 non-null  float64
#  68  review_scores_communication                   27690 non-null  float64
#  69  review_scores_location                        27686 non-null  float64
#  70  review_scores_value                           27684 non-null  float64
#  71  requires_license                              0 non-null      float64
#  72  license                                       0 non-null      float64
#  73  instant_bookable                              31907 non-null  object
#  74  calculated_host_listings_count                31907 non-null  int64
#  75  calculated_host_listings_count_entire_homes   31907 non-null  int64
#  76  calculated_host_listings_count_private_rooms  31907 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   31907 non-null  int64
#  78  region_id                                     31907 non-null  int64
#  79  region_name                                   31907 non-null  object
#  80  region_parent_id                              31907 non-null  int64
#  81  region_parent_name                            31907 non-null  object
#  82  region_parent_parent_id                       31907 non-null  object
#  83  region_parent_parent_name                     31907 non-null  object
#  84  reviews_per_month                             27692 non-null  float64
# dtypes: float64(27), int64(20), object(38)
# memory usage: 20.7+ MB
#              id                                       listing_url  \
# 0  6.036770e+17   https://www.airbnb.com/rooms/603677011869258126
# 1  2.830102e+07             https://www.airbnb.com/rooms/28301020
# 2  1.141860e+18  https://www.airbnb.com/rooms/1141864011309312026
# 3  1.138644e+07             https://www.airbnb.com/rooms/11386441
# 4  7.673770e+17   https://www.airbnb.com/rooms/767377133564836268
#
#       scrape_id last_searched last_scraped          source  \
# 0  2.025060e+13     6/12/2025    6/22/2025  country scrape
# 1  2.025060e+13     6/12/2025    6/22/2025  country scrape
# 2  2.025060e+13     6/12/2025    6/22/2025  country scrape
# 3  2.025060e+13     6/12/2025    6/22/2025  country scrape
# 4  2.025060e+13     6/12/2025    6/22/2025  country scrape
#
#                                                 name  \
# 0    Tranquil, One Bedroom Apartment close to Dublin
# 1  The Fairy House In The Garden Of Ireland Wicklow.
# 2                 Spacious Double Room in Cloyne.R.6
# 3                      The Cow House Tinode Farmyard
# 4                    1 BedRoom Apartment-Shanagolden
#
#                                          description  \
# 0  Take a break and unwind in the peaceful oasis ...
# 1  Nestled at the foothills of the Wicklow mounta...
# 2  Spacious Double Room Ensuite in the heart of C...
# 3  WINNER of 'BEST HOUSE' 2014 at the Architectur...
# 4  Enjoy easy access to everything from this perf...
#
#                                neighborhood_overview  \
# 0  Located in a small rural village approximately...
# 1  The accomadation is situated in a tranquil rel...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  ...  \
# 0  https://a0.muscache.com/pictures/hosting/Hosti...  ...
# 1  https://a0.muscache.com/pictures/36f378e4-8dc8...  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...  ...
# 3  https://a0.muscache.com/pictures/a80aa3dc-9216...  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  ...
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            0
# 3                                            3
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            4
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms region_id  \
# 0                                           0  13250400
# 1                                           0  13250400
# 2                                           0   1340402
# 3                                           0  13250400
# 4                                           0  13120401
#
#              region_name region_parent_id                region_parent_name  \
# 0      Baltinglass LEA-6           255001            Wicklow County Council
# 1      Baltinglass LEA-6           255001            Wicklow County Council
# 2         Midleton LEA-7            45501               Cork County Council
# 3      Baltinglass LEA-6           255001            Wicklow County Council
# 4  Adare-Rathkeale LEA-6           125002  Limerick City And County Council
#
#   region_parent_parent_id region_parent_parent_name reviews_per_month
# 0                   IE062                  Mid-East              4.30
# 1                   IE062                  Mid-East              3.50
# 2                   IE053                South-West              0.08
# 3                   IE062                  Mid-East              0.07
# 4                   IE051                  Mid-West               NaN
#
# [5 rows x 85 columns]

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.190700e+04  3.190700e+04  3.190700e+04         30716.000000
# mean   5.693874e+17  2.025060e+13  2.146778e+08            13.514195
# std    5.557529e+17  0.000000e+00  2.016137e+08            61.989334
# min    1.153200e+04  2.025060e+13  4.292800e+04             1.000000
# 25%    2.772388e+07  2.025060e+13  4.291205e+07             1.000000
# 50%    6.445270e+17  2.025060e+13  1.387532e+08             2.000000
# 75%    1.120130e+18  2.025060e+13  3.871528e+08             4.000000
# max    1.440870e+18  2.025060e+13  7.005409e+08          1607.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               30716.000000  31907.000000  31907.000000  31907.000000
# mean                   32.602911     53.159706     -7.791168      4.222678
# std                   274.654506      0.829529      1.412042      2.728867
# min                     1.000000     51.432700    -10.541630      1.000000
# 25%                     1.000000     52.595520     -9.091895      2.000000
# 50%                     2.000000     53.320949     -7.767457      4.000000
# 75%                     5.000000     53.421420     -6.278523      6.000000
# max                  8731.000000     55.382000     -6.015970     16.000000
#
#           bathrooms      bedrooms  ...  review_scores_value  requires_license  \
# count  26165.000000  29640.000000  ...         27684.000000               0.0
# mean       1.643531      2.119467  ...             4.725148               NaN
# std        1.142169      1.439420  ...             0.360788               NaN
# min        0.000000      0.000000  ...             1.000000               NaN
# 25%        1.000000      1.000000  ...             4.660000               NaN
# 50%        1.000000      2.000000  ...             4.820000               NaN
# 75%        2.000000      3.000000  ...             4.930000               NaN
# max       40.000000     41.000000  ...             5.000000               NaN
#
#        license  calculated_host_listings_count  \
# count      0.0                    31907.000000
# mean       NaN                        9.151315
# std        NaN                       30.433224
# min        NaN                        1.000000
# 25%        NaN                        1.000000
# 50%        NaN                        1.000000
# 75%        NaN                        3.000000
# max        NaN                      227.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 31907.000000
# mean                                      7.651111
# std                                      29.851923
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     227.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  31907.000000
# mean                                       1.404582
# std                                        5.625129
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       81.000000
#
#        calculated_host_listings_count_shared_rooms     region_id  \
# count                                 31907.000000  3.190700e+04
# mean                                      0.042279  7.917672e+06
# std                                       0.529455  5.903511e+06
# min                                       0.000000  1.310400e+06
# 25%                                       0.000000  1.360400e+06
# 50%                                       0.000000  1.315040e+07
# 75%                                       0.000000  1.326041e+07
# max                                      10.000000  1.326043e+07
#
#        region_parent_id  reviews_per_month
# count      31907.000000       27692.000000
# mean      154251.959382           1.518150
# std        93845.277108           1.759258
# min        15001.000000           0.010000
# 25%        65001.000000           0.330000
# 50%       155001.000000           0.930000
# 75%       265002.000000           2.040000
# max       265011.000000          31.860000
#
# [8 rows x 47 columns]

# %%
# Save the cleaned dataset to a new CSV file
df.to_csv('Ireland_Airbnb_Listing__Detailed__Investor.csv', index=False)
